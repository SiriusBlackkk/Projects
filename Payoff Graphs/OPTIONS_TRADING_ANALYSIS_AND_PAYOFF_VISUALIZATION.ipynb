# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.36)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.5.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.23.5)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.4)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2023.4)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.0)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2023.11.17)

# %% [markdown]
# **IMPORTING THE LIBRARIES**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from datetime import date


import warnings
warnings.filterwarnings("ignore")

# to fetch data
import yfinance as yf

# %% [markdown]
# **IMPORTING DATA FOR OPTIONS**

# %%
symbol = '^SPX'  #the ticker of the stock whose data is to be taken out
dfo = yf.Ticker(symbol)

# %%
dfo.options  #to get the date of different expiration time
# Out:
# ('2024-02-02',
#  '2024-02-05',
#  '2024-02-06',
#  '2024-02-07',
#  '2024-02-08',
#  '2024-02-09',
#  '2024-02-12',
#  '2024-02-13',
#  '2024-02-14',
#  '2024-02-15',
#  '2024-02-16',
#  '2024-02-20',
#  '2024-02-21',
#  '2024-02-22',
#  '2024-02-23',
#  '2024-02-26',
#  '2024-02-27',
#  '2024-02-28',
#  '2024-02-29',
#  '2024-03-01',
#  '2024-03-04',
#  '2024-03-05',
#  '2024-03-08',
#  '2024-03-11',
#  '2024-03-15',
#  '2024-03-28',
#  '2024-04-19',
#  '2024-04-30',
#  '2024-05-17',
#  '2024-05-31',
#  '2024-06-21',
#  '2024-06-28',
#  '2024-07-19',
#  '2024-08-16',
#  '2024-09-20',
#  '2024-09-30',
#  '2024-10-18',
#  '2024-11-15',
#  '2024-12-20',
#  '2024-12-31',
#  '2025-01-17',
#  '2025-02-21',
#  '2025-03-21',
#  '2025-06-20',
#  '2025-12-19',
#  '2026-03-20',
#  '2026-12-18',
#  '2027-12-17',
#  '2028-12-15',
#  '2029-12-21')

# %%
type(dfo.options)
# Out:
# tuple

# %%
dfo_exp = dfo.option_chain(dfo.options[1])  #to get data of next recent expiry date

# %%
print(type(dfo_exp))
# Out:
# <class 'yfinance.ticker.Options'>

# %%
dfo_exp.calls #Data for call options
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0    SPXW240205C01200000 2024-01-19 15:36:15+00:00  1200.0    3594.75  3752.8
# 1    SPXW240205C04050000 2024-01-02 20:36:11+00:00  4050.0     697.54   854.2
# 2    SPXW240205C04100000 2024-01-02 20:36:11+00:00  4100.0     648.25   803.6
# 3    SPXW240205C04250000 2024-02-02 16:57:05+00:00  4250.0     701.60   704.3
# 4    SPXW240205C04300000 2024-01-30 15:00:30+00:00  4300.0     627.23   653.8
# ..                   ...                       ...     ...        ...     ...
# 125  SPXW240205C05150000 2024-02-02 18:19:48+00:00  5150.0       0.05     0.0
# 126  SPXW240205C05200000 2024-02-02 18:03:10+00:00  5200.0       0.05     0.0
# 127  SPXW240205C05300000 2024-01-30 20:29:14+00:00  5300.0       0.10     0.0
# 128  SPXW240205C05400000 2024-01-30 15:20:03+00:00  5400.0       0.05     0.0
# 129  SPXW240205C05600000 2023-12-20 19:05:56+00:00  5600.0       0.20     0.0
#
#          ask    change  percentChange  volume  openInterest  \
# 0    3761.30   0.00000       0.000000     2.0             1
# 1     862.10   0.00000       0.000000     1.0             1
# 2     812.10   0.00000       0.000000     1.0             1
# 3     711.70  90.28998      14.769918     2.0             2
# 4     660.80   0.00000       0.000000     1.0            11
# ..       ...       ...            ...     ...           ...
# 125     0.10  -0.05000     -50.000000   212.0           372
# 126     0.05  -0.02000     -28.571426  1107.0           933
# 127     0.05   0.00000       0.000000   254.0           465
# 128     0.05   0.00000       0.000000     1.0           416
# 129     0.15   0.00000       0.000000     NaN            10
#
#      impliedVolatility  inTheMoney contractSize currency
# 0             5.329593        True      REGULAR      USD
# 1             0.000010        True      REGULAR      USD
# 2             0.000010        True      REGULAR      USD
# 3             0.743228        True      REGULAR      USD
# 4             0.668643        True      REGULAR      USD
# ..                 ...         ...          ...      ...
# 125           0.140634       False      REGULAR      USD
# 126           0.160165       False      REGULAR      USD
# 127           0.216805       False      REGULAR      USD
# 128           0.271492       False      REGULAR      USD
# 129           0.411627       False      REGULAR      USD
#
# [130 rows x 14 columns]

# %%
dfo_exp.puts #Data for put options
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0    SPXW240205P01800000 2023-12-12 20:02:05+00:00  1800.0       0.07    0.0
# 1    SPXW240205P02000000 2023-12-27 14:55:50+00:00  2000.0       0.05    0.0
# 2    SPXW240205P02200000 2023-12-27 16:55:07+00:00  2200.0       0.05    0.0
# 3    SPXW240205P02400000 2024-01-04 18:47:32+00:00  2400.0       0.05    0.0
# 4    SPXW240205P02600000 2024-01-11 19:59:39+00:00  2600.0       0.05    0.0
# ..                   ...                       ...     ...        ...    ...
# 138  SPXW240205P05025000 2024-02-02 17:37:55+00:00  5025.0      66.74   64.4
# 139  SPXW240205P05030000 2024-02-02 17:29:40+00:00  5030.0      70.00   69.2
# 140  SPXW240205P05050000 2024-02-01 20:48:00+00:00  5050.0     147.20   90.9
# 141  SPXW240205P05125000 2024-01-29 18:33:37+00:00  5125.0     221.19  164.2
# 142  SPXW240205P05150000 2024-02-01 17:58:55+00:00  5150.0     261.64  191.0
#
#         ask     change  percentChange  volume  openInterest  \
# 0      0.10   0.000000       0.000000     3.0             6
# 1      0.10   0.000000       0.000000     NaN            53
# 2      0.10   0.000000       0.000000     1.0             3
# 3      0.05   0.000000       0.000000     1.0           206
# 4      0.00   0.000000       0.000000     1.0           178
# ..      ...        ...            ...     ...           ...
# 138   70.60 -34.040000     -33.776543     1.0             2
# 139   75.40 -56.339996     -44.593950    69.0             4
# 140   97.90   0.000000       0.000000     7.0            11
# 141  171.10   0.000000       0.000000     1.0             2
# 142  198.10   0.000000       0.000000     5.0             7
#
#      impliedVolatility  inTheMoney contractSize currency
# 0             2.765628       False      REGULAR      USD
# 1             2.484379       False      REGULAR      USD
# 2             2.234379       False      REGULAR      USD
# 3             1.914063       False      REGULAR      USD
# 4             0.500005       False      REGULAR      USD
# ..                 ...         ...          ...      ...
# 138           0.068552        True      REGULAR      USD
# 139           0.063608        True      REGULAR      USD
# 140           0.131723        True      REGULAR      USD
# 141           0.165169        True      REGULAR      USD
# 142           0.230751        True      REGULAR      USD
#
# [143 rows x 14 columns]

# %%
symbol = '^SPX'
end = date.today()
start = end.replace(year = 2022)


# Read data
df = yf.download(symbol,start,end)

df.tail()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2024-01-26  4888.910156  4906.689941  4881.470215  4890.970215  4890.970215
# 2024-01-29  4892.950195  4929.310059  4887.399902  4927.930176  4927.930176
# 2024-01-30  4925.890137  4931.089844  4916.270020  4924.970215  4924.970215
# 2024-01-31  4899.189941  4906.750000  4845.149902  4845.649902  4845.649902
# 2024-02-01  4861.109863  4906.970215  4853.520020  4906.189941  4906.189941
#
#                 Volume
# Date
# 2024-01-26  3353400000
# 2024-01-29  3525160000
# 2024-01-30  3836130000
# 2024-01-31  4696120000
# 2024-02-01  4386090000

# %%
print(end)
print(start)
# Out:
# 2024-02-02
# 2022-02-02

# %% [markdown]
# # **PAYOFF FROM CALL AND PUT OPTIONS**

# %% [markdown]
# # **Call option**
# payoff=max(-C, S - X - C)

# %% [markdown]
# # **Put option**
# payoff=max(-P, X - S - P)
#
# P and C are premiums of calls and puts
#
# S is the stock price
#
# X is the strike price

# %%
def payoff(option_type, premium, S, X):
  Payoff = 0


  if option_type=='C':
    Payoff=(max(-premium, S-X-premium))
    return Payoff
  elif option_type=='P':
    Payoff=(max(-premium, X-S-premium))
    return Payoff
  else:
    print('option type not supported')

# %% [markdown]
# **Checking the output of payoff function**

# %%
payoff('C', 10, 120,100)  #answer displayed should be 10
# Out:
# 10

# %%
payoff('Z', 10, 120, 100)  #answer displayed should be option type not supported
# Out:
# option type not supported

# %%
payoff('P', 10, 120, 100)  #answer displayed should be -10
# Out:
# -10

# %% [markdown]
# # **PAYOFF GRAPHS**

# %% [markdown]
# **CALL OPTION**

# %%
X = dfo_exp.calls['strike'][0]
premium = dfo_exp.calls['lastPrice'][0]

# %%
StockPrice = np.arange(0, 6000)
Payoff = [payoff('C', premium, i, X) for i in StockPrice]

# %%
#PLOTTING THE PAYOFF GRAPH FOR CALL OPTION
plt.plot(StockPrice, Payoff, label = 'payoff line')
plt.xlabel('Stock Price')
plt.ylabel('payoff')
plt.title('Call option Payoff at Expiry')
plt.grid(True)

#breakeven point is when payoff is 0 or S=X+C
plt.plot(X+premium, 0, 'ro', label = 'breakeven point')
plt.legend()

# %% [markdown]
# **PUT OPTION**

# %%
X = dfo_exp.puts['strike'][len(dfo_exp.puts)-1]
premium = dfo_exp.puts['lastPrice'][len(dfo_exp.puts)-1]

# %%
StockPrice = np.arange(0, 6000)
Payoff = [payoff('P', premium, i, X) for i in StockPrice]

# %%
#PLOTTING THE PAYOFF GRAPH FOR PUT OPTION

plt.plot(StockPrice, Payoff, label = 'payoff line')
plt.xlabel('Stock Price')
plt.ylabel('payoff')
plt.title('Put option Payoff at Expiry')
plt.grid(True)

#breakeven point is when payoff is 0 or S=X+C
plt.plot(X-premium, 0, 'ro', label = 'breakeven point')
plt.legend()
